# %% [markdown]
# In pandas, both **Series** and **DataFrame** are fundamental data structures used to handle data. Here’s a breakdown of the key differences between them:
#
# ### 1. **Series**
# - **1-Dimensional**: A Series is a one-dimensional array-like structure, similar to a list or an array. It can hold data of any single data type (integers, floats, strings, etc.).
# - **Single Column**: Essentially, a Series represents a single column of data.
# - **Labeled Index**: Each element in a Series has a unique index (labels) which can be custom-defined or automatically generated.
# - **Homogeneous Data**: A Series contains elements of a single data type.
#
# #### Example:
# ```python
# import pandas as pd
#
# # Create a Series
# s = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
# print(s)
# ```
#
# Output:
# ```
# a    10
# b    20
# c    30
# d    40
# dtype: int64
# ```
#
# ### 2. **DataFrame**
# - **2-Dimensional**: A DataFrame is a two-dimensional, table-like data structure that can hold multiple rows and columns.
# - **Multiple Columns**: It’s essentially a collection of multiple Series objects, where each Series represents a column in the DataFrame.
# - **Labeled Index and Columns**: A DataFrame has both labeled row indices and column labels.
# - **Heterogeneous Data**: Columns in a DataFrame can contain data of different types (e.g., integers, floats, strings).
#
# #### Example:
# ```python
# # Create a DataFrame
# data = {'Name': ['Alice', 'Bob', 'Charlie'],
#         'Age': [25, 30, 35],
#         'Salary': [50000, 60000, 70000]}
#
# df = pd.DataFrame(data)
# print(df)
# ```
#
# Output:
# ```
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000
# ```
#
# ### Key Differences:
# | Feature          | Series                            | DataFrame                            |
# |------------------|-----------------------------------|--------------------------------------|
# | **Dimension**    | 1D (one-dimensional)              | 2D (two-dimensional)                 |
# | **Data**         | Single column of data             | Multiple rows and columns of data    |
# | **Data Type**    | Homogeneous (one data type)       | Heterogeneous (multiple data types)  |
# | **Structure**    | Similar to a list or array        | Similar to a table or spreadsheet    |
# | **Indexing**     | Only row index                   | Row and column indices               |
#
# In summary, a Series is a single column, while a DataFrame is a collection of columns, making the DataFrame more flexible and powerful for working with structured data.

# %% [markdown]
# # Creating Pandas Series

# %%
import pandas as pd
colors = pd.Series(["Red", "Green", "Blue"])
colors

cars = pd.Series(["ferrari", "Lambo", "Dodge"])

cars

# Converting 2 series into a dataframe
cars_df = pd.DataFrame({"Cars": cars, "Colors": colors})

cars_df
# Out:
#       Cars Colors
# 0  ferrari    Red
# 1    Lambo  Green
# 2    Dodge   Blue

# %% [markdown]
# # Reading from and Converting Pandas Dataframe to CSV

# %%
car_sales = pd.read_csv("car-sales.csv")

# Exporting without (index = False) makes it so that it does not export the indexes
# car_sales.to_csv("exported-car-sales.csv")
car_sales.to_csv("exported-car-sales.csv", index=False)

# %%
car_sales2 = pd.read_csv("exported-car-sales.csv")

print(car_sales2)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Checking Datatypes in Pandas Dataframe using **.dtypes** method

# %%
# datatypes in the car sales data frame
car_sales2.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %% [markdown]
# # Get indexes of your dataframe using **.index** method

# %%
# getting indexes of your dataframe
car_sales2.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %% [markdown]
#  *.describe() only works on numeric columns*
#
# output does not include the 'price' column since it has $ sign before numeric value so it is treated as an object
#
# The **.describe()** function in pandas provides summary statistics of a DataFrame or a Series. It generates descriptive statistics such as **count**, **mean**, **standard deviation**, **minimum**, **maximum**, and **percentiles (25%, 50%, and 75%)** for numeric columns by default. If used with non-numeric data, it will return statistics like **count**, **unique values**, **top (most frequent value)**, and** frequency of the top value**.
#
# ## Here's how it works:
#
# ### For numeric data, it returns:
#
# - **count:** Number of non-null entries
# - **mean:** Average of the values
# - **std:** Standard deviation
# - **min:** Minimum value
# - **25%, 50%, 75%:** Percentiles (Quartiles)
# - **max:** Maximum value
#
# ### For non-numeric data, it returns:
#
# - **count:** Number of non-null entries
# - **unique:** Number of unique values
# - **top:** Most frequent value
# - **freq:** Frequency of the most frequent value

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %% [markdown]
# # **.info()** gives combined information of **.index** and **.dtypes**
# basically indexes and dataframe

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %% [markdown]
# # **.mean()** shows us average of our numerical columns

# %%
# car_sales.mean() # this will give us an error since it is depreciated, new way requires all data to be numeric for this to work
# this will give us the mean of the numeric columns only
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %% [markdown]
# # To select a single column in a datafrarame, you can use the following syntax:
#
# *df['column_name']*

# %%
car_sales["Doors"].sum()
a = 5

# %% [markdown]
# # Length and Size of Dataframe

# %%
print("rows in df", len(car_sales))  # how many rows df has
print("items in df", car_sales.size)  # how many items in dataframe
# Out:
# rows in df 10
# items in df 50

# %% [markdown]
# # How to check **First** and **Last** rows of Dataframe Using **.head** and **.tail**

# %%
car_sales.head()  # return top 5 rows of dataframe by default

# return top 7 rows of dataframe , basically you can adjust how many rows you want via param inside head()

car_sales.head(7)  # top 7 rows

car_sales.tail()  # return bottom 5 rows of dataframe

car_sales.tail(3)  # add a number inside .tail() to adjust output of .tail()
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100KM  \
# 7   honda   Blue          54738      4  7000.0    5.0             8.0
# 8  toyota  White          60000      4  6250.0    5.0             7.0
# 9  nissan  White          31600      4  9700.0    5.0             6.5
#
#    Total fuel used (L)  Number of wheels
# 7              4379.04                 4
# 8              4200.00                 4
# 9              2054.00                 4

# %% [markdown]
# # .loc() and .iloc()
# - **loc** is short for location , refers to **index**
#
# - **iloc** refers to **position** rather than index

# %%
# using index = ""  we can modify the default index of the series
animals = pd.Series(["cat", "dog", "bird", "panda",
                    "snake"], index=[0, 3, 9, 8, 3])

# %%
animals.loc[3]  # retrive items that have index 3
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[3]  # returns panda since it is on position 3 but has index 8
# Out:
# 'panda'

# %% [markdown]
# # Slicing with loc and iloc

# %%
animals.iloc[:3]  # gives us items on first 3 positions
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]  # gives us items on first 3 indexes
# animals.loc[:3] # gives us error since index numbers are not consistent

# so it is similar to .head(4)

car_sales.head(4)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %% [markdown]
# # 2 Ways of Selecting columns
#
# 1. Using dot notation
# 2. Using bracket notation
#
# Difference: Dot notation does not work if the column name has a gap, then you need to use bracket notation

# %%
# using bracket notation
car_sales["Make"]

# using dot notation
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
# COLUMN name with space
car_sales["Odometer (KM)"]  # this one works

# car_sales.Odometer (KM) # this one returns AttributeError
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %% [markdown]
# # Accessing Columns with filter / condition

# %%
# Using boolean indexing
# returns rows in "Make" column where make == "Toyota"
car_sales[car_sales["Make"] == "Toyota"]

# returns rows in "Odometer (KM)" column where odometer > 100000
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %% [markdown]
# # Crosstab is used to compare 2 columns

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %% [markdown]
# # Comparing more than 2 columns (Groupby)

# %%
# car_sales.groupby(["Make"]).mean() # works only on numeric columns so this will give error since price is object type

# car_sales.groupby(["Make"]).mean() # column name does not necessarily need to be in [] brackets
# selecting only numeric columns which are type int or float
numeric_columns = car_sales.select_dtypes(include=['float', 'int']).columns
# grouping by "Make" and selecting only numeric columns to find mean
numeric_mean = car_sales.groupby("Make")[numeric_columns].mean()

numeric_mean
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %% [markdown]
# # Plotting Columns with Pandas

# %%
# uses matplotlib behind the scenes , not required to import matplotlib
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Plotting Histograms with Pandas

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %% [markdown]
# # Converting object Price column into integer

# %%
print(car_sales)
# converting Price column in car_sales df to float by first removing $ and , from the str value
# and then converting it to float
car_sales["Price"] = car_sales["Price"].str.replace(
    '[\$\,]', '', regex=True).astype(float)
print(car_sales)

car_sales.plot()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# ...

# %% [markdown]
# # Manipulating Data with Pandas

# %%
# Pandas requires to reassign column to save changes
car_sales["Make"] = car_sales["Make"].str.lower()

# %% [markdown]
# # Fixing Missing data (Using .fillna() method)

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
print(car_sales_missing)

# Using .fillna() method
# car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean()) # fills NaN values with mean of column's other values

# Instead of reassigning column to save changes we can also use inplace = True parameter in fillna()

car_sales_missing["Odometer"].fillna(
    car_sales_missing["Odometer"].mean(), inplace=True)

car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700
# C:\Users\ABC\AppData\Local\Temp\ipykernel_14244\4183715962.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# # Removing Missing data (Using .dropna() method)

# %%
car_sales_missing.dropna(inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %% [markdown]
# # Creating New Columns

# %%
# Create a new pd series
seats_column = pd.Series([5, 5, 5, 3, 2])
# Assign column name and set equal to series
car_sales["Seats"] = seats_column

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    3.0
# 4  nissan  White         213095      4   3500.0    2.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
# Filling the missing data  "NaN" with 5 seats
car_sales["Seats"].fillna(5, inplace=True)
car_sales
# Out:
# C:\Users\ABC\AppData\Local\Temp\ipykernel_14244\2531475344.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales["Seats"].fillna(5, inplace=True)
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    3.0
# 4  nissan  White         213095      4   3500.0    2.0
# ...

# %% [markdown]
# # Creating a new Column with a List

# %%
import numpy as np
import random
# list needs to same size as number of rows in df or else we get error , same goes for numpy arrays
fuel_economy = [random.randrange(2, 9, 2) for i in range(10)]
print(fuel_economy)
# to get values that have 0.5 step size , we can use numpy

# Generate a list of random fuel economy values with steps of 0.5 between 2 and 9
fuel_economy = [random.choice(np.arange(2, 9, 0.5)) for i in range(10)]
print(fuel_economy)

car_sales["Fuel per 100KM"] = fuel_economy

car_sales
# Out:
# [4, 8, 6, 6, 8, 8, 4, 4, 2, 4]
# [5.0, 5.5, 5.0, 7.0, 2.0, 3.0, 5.5, 8.0, 7.0, 6.5]
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   4000.0    5.0             5.0
# 1   honda    Red          87899      4   5000.0    5.0             5.5
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    3.0             7.0
# 4  nissan  White         213095      4   3500.0    2.0             2.0
# 5  toyota  Green          99213      4   4500.0    5.0             3.0
# 6   honda   Blue          45698      4   7500.0    5.0             5.5
# 7   honda   Blue          54738      4   7000.0    5.0             8.0
# 8  toyota  White          60000      4   6250.0    5.0             7.0
# 9  nissan  White          31600      4   9700.0    5.0             6.5

# %% [markdown]
# # Creating a new column from an existing column

# %%
# Creating a total fuel used column based on odometer and fuel per 100km
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"] / \
    100 * car_sales["Fuel per 100KM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             5.0
# 1   honda    Red          87899      4   5000.0    5.0             5.5
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    3.0             7.0
# 4  nissan  White         213095      4   3500.0    2.0             2.0
# 5  toyota  Green          99213      4   4500.0    5.0             3.0
# 6   honda   Blue          45698      4   7500.0    5.0             5.5
# 7   honda   Blue          54738      4   7000.0    5.0             8.0
# 8  toyota  White          60000      4   6250.0    5.0             7.0
# 9  nissan  White          31600      4   9700.0    5.0             6.5
#
#    Total fuel used (L)
# 0             7502.150
# 1             4834.445
# 2             1627.450
# 3              782.530
# 4             4261.900
# 5             2976.390
# ...

# %% [markdown]
# # Creating a column from a single value

# %%
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             5.0
# 1   honda    Red          87899      4   5000.0    5.0             5.5
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    3.0             7.0
# 4  nissan  White         213095      4   3500.0    2.0             2.0
# 5  toyota  Green          99213      4   4500.0    5.0             3.0
# 6   honda   Blue          45698      4   7500.0    5.0             5.5
# 7   honda   Blue          54738      4   7000.0    5.0             8.0
# 8  toyota  White          60000      4   6250.0    5.0             7.0
# 9  nissan  White          31600      4   9700.0    5.0             6.5
#
#    Total fuel used (L)  Number of wheels
# 0             7502.150                 4
# 1             4834.445                 4
# 2             1627.450                 4
# ...

# %% [markdown]
# # Sample Dataframe using .sample() method

# %% [markdown]
# In pandas, the `frac` parameter in the `sample()` method is used to specify the fraction of the DataFrame to sample. Here’s a breakdown of what `df.sample(frac=1)` does:
#
# ### Explanation of `frac`:
#
# - **`frac` Parameter**: This parameter determines the fraction of rows to return from the DataFrame. It takes a value between `0` and `1`, where:
#   - `frac=1` means you want to sample 100% of the DataFrame (i.e., all rows).
#   - `frac=0.5` means you want to sample 50% of the DataFrame.
#   - `frac=0.25` means you want to sample 25% of the DataFrame, and so on.
#
# ### What `df.sample(frac=1)` Does:
#
# 1. **Shuffles the DataFrame**: When you set `frac=1`, you're asking pandas to return all the rows, but in a randomly shuffled order. This is often used to randomize the order of rows in a DataFrame.
#
# 2. **Returns a New DataFrame**: The result is a new DataFrame with the same rows as the original DataFrame, but the order of the rows is random.
#
# ### Example:
#
# ```python
# import pandas as pd
#
# # Sample DataFrame
# data = {'A': [1, 2, 3, 4, 5],
#         'B': ['a', 'b', 'c', 'd', 'e']}
#
# df = pd.DataFrame(data)
#
# # Shuffle the DataFrame
# shuffled_df = df.sample(frac=1)
#
# print(shuffled_df)
# ```
#
# ### Output:
# The output will display the original DataFrame rows in a random order. For example:
#
# ```
#    A  B
# 2  3  c
# 0  1  a
# 4  5  e
# 1  2  b
# 3  4  d
# ```
#
# ### Summary:
# - **`df.sample(frac=1)`** shuffles the DataFrame, returning all rows in a random order. It is a common technique for randomizing data, especially useful in tasks like cross-validation in machine learning or when preparing data for analysis.

# %%
# Shuffle the DataFrame using sample() with the frac parameter set to 1
# Save the the shuffled DataFrame to a new variable
car_sales = car_sales.sample(frac=1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             5.0
# 5  toyota  Green          99213      4   4500.0    5.0             3.0
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 6   honda   Blue          45698      4   7500.0    5.0             5.5
# 3     bmw  Black          11179      5  22000.0    3.0             7.0
# 9  nissan  White          31600      4   9700.0    5.0             6.5
# 8  toyota  White          60000      4   6250.0    5.0             7.0
# 1   honda    Red          87899      4   5000.0    5.0             5.5
# 4  nissan  White         213095      4   3500.0    2.0             2.0
# 7   honda   Blue          54738      4   7000.0    5.0             8.0
#
#    Total fuel used (L)  Number of wheels
# 0             7502.150                 4
# 5             2976.390                 4
# 2             1627.450                 4
# ...

# %% [markdown]
# # Reset Indexes
# resets indexes back to normal

# %%
# Reset the indexes of the shuffled DataFrame
car_sales.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0      0  toyota  White         150043      4   4000.0    5.0             5.0
# 1      5  toyota  Green          99213      4   4500.0    5.0             3.0
# 2      2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3      6   honda   Blue          45698      4   7500.0    5.0             5.5
# 4      3     bmw  Black          11179      5  22000.0    3.0             7.0
# 5      9  nissan  White          31600      4   9700.0    5.0             6.5
# 6      8  toyota  White          60000      4   6250.0    5.0             7.0
# 7      1   honda    Red          87899      4   5000.0    5.0             5.5
# 8      4  nissan  White         213095      4   3500.0    2.0             2.0
# 9      7   honda   Blue          54738      4   7000.0    5.0             8.0
#
#    Total fuel used (L)  Number of wheels
# 0             7502.150                 4
# ...

# %% [markdown]
# Notice the index numbers have been changed to have order (start from 0).

# %% [markdown]
# # Change the **Odometer** values from *kilometers* to *miles* using a *Lambda function*

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White      93776.875      4   4000.0    5.0             5.0
# 5  toyota  Green      62008.125      4   4500.0    5.0             3.0
# 2  toyota   Blue      20343.125      3   7000.0    5.0             5.0
# 6   honda   Blue      28561.250      4   7500.0    5.0             5.5
# 3     bmw  Black       6986.875      5  22000.0    3.0             7.0
# 9  nissan  White      19750.000      4   9700.0    5.0             6.5
# 8  toyota  White      37500.000      4   6250.0    5.0             7.0
# 1   honda    Red      54936.875      4   5000.0    5.0             5.5
# 4  nissan  White     133184.375      4   3500.0    2.0             2.0
# 7   honda   Blue      34211.250      4   7000.0    5.0             8.0
#
#    Total fuel used (L)  Number of wheels
# 0             7502.150                 4
# 5             2976.390                 4
# 2             1627.450                 4
# ...

# %% [markdown]
# # Change the title of the **Odometer (KM)** to represent *miles* instead of *kilometers* using **.rename()** method

# %%
# Change the title of the Odometer (KM) to represent miles instead of kilometers
car_sales = car_sales.rename(columns={"Odometer (KM)": "Odometer (Miles)"})
car_sales
# Out:
#      Make Colour  Odometer (Miles)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         93776.875      4   4000.0    5.0             5.0
# 5  toyota  Green         62008.125      4   4500.0    5.0             3.0
# 2  toyota   Blue         20343.125      3   7000.0    5.0             5.0
# 6   honda   Blue         28561.250      4   7500.0    5.0             5.5
# 3     bmw  Black          6986.875      5  22000.0    3.0             7.0
# 9  nissan  White         19750.000      4   9700.0    5.0             6.5
# 8  toyota  White         37500.000      4   6250.0    5.0             7.0
# 1   honda    Red         54936.875      4   5000.0    5.0             5.5
# 4  nissan  White        133184.375      4   3500.0    2.0             2.0
# 7   honda   Blue         34211.250      4   7000.0    5.0             8.0
#
#    Total fuel used (L)  Number of wheels
# 0             7502.150                 4
# 5             2976.390                 4
# ...
